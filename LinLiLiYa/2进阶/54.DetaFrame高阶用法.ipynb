# %%
import pandas as pd

# %%
students=pd.DataFrame({
    "001": {"姓名": "小陈", "考试1": 85, "考试2": 95, "考试3": 92},
    "002": {"姓名": "小李", "考试1": 91, "考试2": 92, "考试3": 94},
    "003": {"姓名": "小王", "考试1": 86, "考试2": 81, "考试3": 89},
    "004": {"姓名": "小张", "考试1": 79, "考试2": 89, "考试3": 95},
    "005": {"姓名": "小赵", "考试1": 96, "考试2": 91, "考试3": 91},
    "006": {"姓名": "小周", "考试1": 81, "考试2": 89, "考试3": 92}
}).T
students
# Out:
#      姓名 考试1 考试2 考试3
# 001  小陈  85  95  92
# 002  小李  91  92  94
# 003  小王  86  81  89
# 004  小张  79  89  95
# 005  小赵  96  91  91
# 006  小周  81  89  92

# %% [markdown]
# 计算学生的平均成绩:

# %%
average=students.loc[:,"考试1":"考试3"].mean(axis=1)
#切掉名字后 提取数据列 在用mean函数求平均 axis=1 表示行方向
name=students.loc[:,"姓名"]
#提取姓名列

# %%
#组合name和average
student_average=pd.DataFrame({"姓名":name,"平均分":average})
student_average
# Out:
#      姓名        平均分
# 001  小陈  90.666667
# 002  小李  92.333333
# 003  小王  85.333333
# 004  小张  87.666667
# 005  小赵  92.666667
# 006  小周  87.333333

# %% [markdown]
# 展示信息 describe()

# %%
students.describe()
#count 表示个数  
#unique 表示不重复个数
#top 值
#freq 值出现的频率
# Out:
#         姓名  考试1  考试2  考试3
# count    6    6    6    6
# unique   6    6    5    5
# top     小陈   85   89   92
# freq     1    1    2    2

# %% [markdown]
# 为什么上面展示的信息是这样的呢?
# 是因为有字符串类型的问题所导致整个类型为object
# 转换为int即可：
# students.loc[:, ["考试1", "考试2", "考试3"]].astype(int).describe()

# %%
students.loc[:, ["考试1", "考试2", "考试3"]].astype(int).describe()
# Out:
#              考试1        考试2        考试3
# count   6.000000   6.000000   6.000000
# mean   86.333333  89.500000  92.166667
# std     6.314006   4.722288   2.136976
# min    79.000000  81.000000  89.000000
# 25%    82.000000  89.000000  91.250000
# 50%    85.500000  90.000000  92.000000
# 75%    89.750000  91.750000  93.500000
# max    96.000000  95.000000  95.000000
