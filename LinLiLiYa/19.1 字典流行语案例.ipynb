# %%
流行语 = {
    "数智化": "数字化和智能化的融合体，即在数字化基础上引入智能化高级技术，如自主学习、决策优化等，以提高生产效率、优化资源配置等，是新型工业化的鲜明特征和形成新质生产力的重要途径"
}
# 向字典中添加流行语及其解释
流行语["智能向善"] = (
    "指人工智能的发展必须有利于更好增进人类福祉，既推动产业变革和经济发展，又让社会更加美好，实现可持续发展，是打造全球人工智能良好生态的基石。"
)
流行语["未来产业"] = (
    "指由前沿技术驱动，具有战略性、引领性、颠覆性的前瞻性新兴产业，包括未来制造、未来信息、未来材料等新赛道，其突破和发展将为经济带来新动力和变革。"
)
流行语["city不city"] = (
    "出自美国博主保保熊的短视频，‘city’本义是城市，这里指时髦、洋气、现代化，又指刺激、开心的感觉。‘city不city’即‘时髦不时髦’‘洋气不洋气’等，因外国游客来华旅游增多而走红。"
)
流行语["硬控"] = (
    "最早来源于游戏，指使玩家在一定时间内无法操控自己角色的技能。后扩展到社交语境，形容某个事物或现象对人产生强烈吸引力，让人无法转移视线和关注，如‘××硬控我×秒’。"
)
流行语["水灵灵地XXX"] = (
    "出自一位韩国女歌手展示照片拼贴画时说的话，‘水灵灵’多形容人漂亮有精神或动植物润泽有生气，网友效仿造句，使其使用语境扩大，可用于强调、突出，也可用于调侃、自嘲。"
)
流行语["班味"] = (
    "源自网文《一旦上过班，你的气质就会改变了》，指上班后因任务繁重、条件艰苦等，人们表现出的眼神疲惫、面容憔悴、不修边幅等状态，‘去除班味’等说法也广为传播。"
)
流行语["松弛感"] = (
    "因一位博主分享一家人旅游遇行李被退回仍从容应对的经历而引发热议，在2024年巴黎奥运会期间火遍全网，指面对压力时从容应对、善待自己、不慌张、不焦虑的心理状态。"
)
流行语["银发力量"] = (
    "‘银发’借指老年人，‘银发力量’指老年群体在社会各个领域产生的不可忽视的力量，随着老年群体参与社会活动增多，该词越来越流行。"
)
流行语["小孩哥"] = (
    "指在某方面具有过人才能的孩子，社会注重孩子个性发展和综合素质培养，孩子们有更多机会发挥潜能，像有‘小孩哥’11岁能造‘火箭’，‘小孩姐’14岁创下奥运纪录，让成年人自叹不如，故有此称呼。"
)

#查询某个流行语
查询词=input("请输入要查询的流行语：")
if 查询词 in 流行语:
    print(f"{查询词}:{流行语[查询词]}")
else:
    print("未找到该流行语！")
#查询词条数量:
词条数量=len(流行语)
print(f"词条数量:{词条数量}")
# Out:
# 未找到该流行语！
# 词条数量:10
